# %% [markdown]
# # Fire Incidents Metric

# %% [markdown]
# ### By Luis Castellanos

# %% [markdown]
# When I first started looking at datasets, I wanted to find something health-related because of how relevant it would be during these times. But, when I came across this dataset that describes fire incidents in Pittsburgh, I figured it would be an interesting metric since it's not something that I would think about when choosing which neighboorhood to live in. Although it's not the first metric that comes to anyone's mind if they want to live in Pittsburgh, it still holds great weight in places like California that suffer from wildfires often. So, being able to compare the number of fire incidents from one neighboorhood to another may help individuals find the 'best' and safest neighboorhood.

# %% [markdown]
#     This dataset describes the number and type of fire incidents reported to the Pittsburgh Bureau of Fire.

# %%
import pandas as pd
import numpy as np

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
#     Here is a sample of the dataset. It is a list of fire incidents that contains key information, such as the neighboorhood in which the incident occurred, the type of incident, and the date of each.

# %%
# Read the dataset and show the first five items

incidents = pd.read_csv("fireIncidents.csv")
incidents=incidents.dropna(subset=['neighborhood']).reset_index(drop='true') #drop incidents that are not associated with a neighborhood
incidents.head()
# Out:
#       call_no  incident_type  \
# 0  F130000539          112.0
# 1  F130000714          118.0
# 2  F130000772          118.0
# 3  F130001276          142.0
# 4  F130001631          115.0
#
#                                     type_description  \
# 0        Fires in structure other than in a building
# 1                   Trash or rubbish fire, contained
# 2                   Trash or rubbish fire, contained
# 3              Brush or brush-and-grass mixture fire
# 4  Incinerator overload or malfunction, fire conf...
#
#                                          address           alarm_time  alarms  \
# 0    4500 BLOCK LIBERTY AVE, PITTSBURGH PA 15216  2013-01-02T23:34:05       1
# 1    1200 BLOCK CHISLETT ST, PITTSBURGH PA 15206  2013-01-03T16:36:54       1
# 2  5800 BLOCK ELLSWORTH AVE, PITTSBURGH PA 15206  2013-01-03T20:54:02       1
# 3   1100 BLOCK PEMBERTON ST, PITTSBURGH PA 15212  2013-01-06T00:21:30       0
# 4         300 BLOCK 3RD AVE, PITTSBURGH PA 15219  2013-01-07T17:16:58       1
#
#   primary_unit  census_tract               neighborhood  council_district  \
# 0      231EN06         903.0                 Bloomfield               7.0
# 1      231EN07        1014.0                Morningside               7.0
# 2      231EN08         705.0                  Shadyside               8.0
# 3      231EN35        2708.0           Brighton Heights               1.0
# 4      231EN04         201.0  Central Business District               6.0
#
#    ward         tract  public_works_division  pli_division  police_zone  \
# 0   8.0  4.200308e+10                    2.0           8.0          5.0
# 1  10.0  4.200310e+10                    2.0          10.0          5.0
# 2   7.0  4.200307e+10                    2.0           7.0          4.0
# 3  27.0  4.200327e+10                    1.0          27.0          1.0
# 4   1.0  4.200302e+10                    6.0           1.0          2.0
#
#   fire_zone   latitude  longitude
# 0       3-6  40.462918 -79.951864
# 1       3-7  40.479532 -79.928185
# 2      3-11  40.455850 -79.930435
# 3      1-14  40.482827 -80.030415
# 4       1-4  40.438809 -80.001619

# %% [markdown]
#     There are several columns that have no practical use for this metric, like call_no, incident_type, and public_works_division. So, we can choose to only work with the columns that are useful for this metric.

# %%
rel_incidents=incidents[['type_description','neighborhood']]

rel_incidents.head()
# Out:
#                                     type_description  \
# 0        Fires in structure other than in a building
# 1                   Trash or rubbish fire, contained
# 2                   Trash or rubbish fire, contained
# 3              Brush or brush-and-grass mixture fire
# 4  Incinerator overload or malfunction, fire conf...
#
#                 neighborhood
# 0                 Bloomfield
# 1                Morningside
# 2                  Shadyside
# 3           Brighton Heights
# 4  Central Business District

# %% [markdown]
#     Next, we count the number of fire incidents in each neighborhood

# %%
count_incidents=rel_incidents['neighborhood'].value_counts()
count_incidents.head() #sample of the first five neighborhoods
# Out:
# Carrick                      230
# Central Business District    208
# South Side Flats             202
# Squirrel Hill South          200
# Hazelwood                    200
# Name: neighborhood, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
#     We can use a bar graph to visualize the number of fire incidents per neighborhood.

# %%
plt.figure(figsize=(20,10)) # extra room for all the neighborhoods
count_incidents.plot(kind='bar')

# %% [markdown]
#     We have counted the number of incidents for each neighborhood. But, some people may be interested in the frequency of particular types of fire-related incidents. We can start by creating a new DataFrame that lists every instance of every type of incident in each neighborhood (i.e. not unique instances). This may seem pointless, but will be useful later when we need to count the instances.
#     To do this, we first created a dictionary containing each neighborhood, and appended to it each instance of an incident. Then, a data frame was created from the resulting dictionary

# %%
cat_fcount=dict()
i=0
while(i<len(rel_incidents)): #appends all instances to the corresponding neighborhood
    cat_fcount.setdefault(rel_incidents.loc[i]['neighborhood'],[]).append(rel_incidents.loc[i]['type_description'])
    i+=1
    
stacked=pd.DataFrame.from_dict(cat_fcount,orient='index') #creates DataFrame from the dictionary cat_fcount
stacked=stacked.transpose()
stacked.head()
# Out:
#                                     Bloomfield  \
# 0  Fires in structure other than in a building
# 1                                Building fire
# 2        Mobile property (vehicle) fire, Other
# 3                  Special outside fire, Other
# 4                  Outside rubbish fire, Other
#
#                             Morningside  \
# 0      Trash or rubbish fire, contained
# 1  Outside rubbish, trash or waste fire
# 2   Cooking fire, confined to container
# 3  Outside rubbish, trash or waste fire
# 4  Outside rubbish, trash or waste fire
#
#                                        Shadyside  \
# 0               Trash or rubbish fire, contained
# 1  Fuel burner/boiler malfunction, fire confined
# 2                                  Building fire
# 3                                     Grass fire
# 4                                  Building fire
#
#                         Brighton Heights  \
# 0  Brush or brush-and-grass mixture fire
# 1       Trash or rubbish fire, contained
# 2    Cooking fire, confined to container
# 3                          Building fire
# 4    Cooking fire, confined to container
#
#                            Central Business District  \
# 0  Incinerator overload or malfunction, fire conf...
# 1               Outside rubbish, trash or waste fire
# 2                Cooking fire, confined to container
# 3    Dumpster or other outside trash receptacle fire
# 4                Cooking fire, confined to container
#
#                                 Larimer  \
# 0                         Building fire
# 1      Trash or rubbish fire, contained
# 2                Passenger vehicle fire
# 3                  Outside storage fire
# 4  Outside rubbish, trash or waste fire
#
#                                     Carrick  \
# 0                             Building fire
# 1                             Building fire
# 2       Cooking fire, confined to container
# 3                    Passenger vehicle fire
# 4  Off-road vehicle or heavy equipment fire
#
#                        South Side Flats  \
# 0   Cooking fire, confined to container
# 1  Outside rubbish, trash or waste fire
# 2           Outside rubbish fire, Other
# 3           Outside rubbish fire, Other
# 4   Cooking fire, confined to container
#
#                              Squirrel Hill North  \
# 0            Cooking fire, confined to container
# 1            Cooking fire, confined to container
# 2  Fuel burner/boiler malfunction, fire confined
# 3            Cooking fire, confined to container
# 4            Cooking fire, confined to container
#
#                              Homewood North  ...  \
# 0  Construction or demolition landfill fire  ...
# 1               Outside rubbish fire, Other  ...
# 2               Outside rubbish fire, Other  ...
# 3  Construction or demolition landfill fire  ...
# 4          Trash or rubbish fire, contained  ...
#
#                     Spring Garden                                Esplen  \
# 0          Passenger vehicle fire                         Building fire
# 1  Natural vegetation fire, Other                         Building fire
# 2     Outside rubbish fire, Other        Forest, woods or wildland fire
# 3     Outside rubbish fire, Other  Outside rubbish, trash or waste fire
# 4  Natural vegetation fire, Other  Outside rubbish, trash or waste fire
#
#                          Regent Square                            Mt. Oliver  \
# 0  Cooking fire, confined to container           Outside rubbish fire, Other
# 1               Passenger vehicle fire                         Building fire
# 2          Outside rubbish fire, Other  Outside rubbish, trash or waste fire
# 3                        Building fire  Outside rubbish, trash or waste fire
# 4          Special outside fire, Other                         Building fire
#
#                    Summer Hill  \
# 0       Passenger vehicle fire
# 1       Passenger vehicle fire
# 2  Outside rubbish fire, Other
# 3                Building fire
# 4                Building fire
#
#                                     Allegheny West  \
# 0                      Outside rubbish fire, Other
# 1                      Outside rubbish fire, Other
# 2   Commercial Compactor fire, confined to rubbish
# 3                           Passenger vehicle fire
# 4  Dumpster or other outside trash receptacle fire
#
#                                  East Carnegie  \
# 0                                   Grass fire
# 1          Cooking fire, confined to container
# 2  Fires in structure other than in a building
# 3                                Building fire
# 4          Cooking fire, confined to container
#
#                      Mount Oliver Borough  \
# 0    Outside rubbish, trash or waste fire
# 1  Road freight or transport vehicle fire
# 2                           Building fire
# 3    Outside rubbish, trash or waste fire
# 4             Outside rubbish fire, Other
#
#                                      Hays                    Arlington Heights
# 0             Outside rubbish fire, Other          Outside rubbish fire, Other
# 1   Brush or brush-and-grass mixture fire  Cooking fire, confined to container
# 2                           Building fire  Cooking fire, confined to container
# 3  Road freight or transport vehicle fire  Cooking fire, confined to container
# 4             Outside rubbish fire, Other  Cooking fire, confined to container
#
# [5 rows x 91 columns]

# %% [markdown]
#     From this last data frame, we can count the instances of each incident and group them by neighborhood under a new data frame

# %%
final=pd.DataFrame({"type_description":""},index=[0]) 
by_inc=pd.DataFrame    #new, blank, dataFrames
for i in stacked.columns: #iterates through every column (every neighborhood)
    by_inc=pd.DataFrame(stacked[i].value_counts()).reset_index().rename(columns={"index":"type_description"})
        #value_counts() returns a series, but we want a data frame. Line above does this. 
        #The new data frame has the neighborhood as the index, but we don't want that, so we 'reset the index'. This pushes the current index list as a new column named "index"
        #Finally, the line renames the column to match the data it contains
        
    final=pd.merge(final,by_inc,on='type_description',how='outer').fillna(0) #creates one data frame from all the individual data frames for each neighborhood
final=final.set_index('type_description')
final.head() #sample of final dataFrame
# Out:
#                                                  Bloomfield  Morningside  \
# type_description
#                                                         0.0          0.0
# Cooking fire, confined to container                    34.0          5.0
# Building fire                                          28.0          1.0
# Dumpster or other outside trash receptacle fire        11.0          0.0
# Mobile property (vehicle) fire, Other                   9.0          1.0
#
#                                                  Shadyside  Brighton Heights  \
# type_description
#                                                        0.0               0.0
# Cooking fire, confined to container                   51.0              26.0
# Building fire                                         28.0              27.0
# Dumpster or other outside trash receptacle fire        6.0               6.0
# Mobile property (vehicle) fire, Other                  3.0               4.0
#
#                                                  Central Business District  \
# type_description
#                                                                        0.0
# Cooking fire, confined to container                                   50.0
# Building fire                                                         19.0
# Dumpster or other outside trash receptacle fire                       24.0
# Mobile property (vehicle) fire, Other                                  3.0
#
#                                                  Larimer  Carrick  \
# type_description
#                                                      0.0      0.0
# Cooking fire, confined to container                 19.0     46.0
# Building fire                                       41.0     70.0
# Dumpster or other outside trash receptacle fire      3.0      2.0
# Mobile property (vehicle) fire, Other                4.0      3.0
#
#                                                  South Side Flats  \
# type_description
#                                                               0.0
# Cooking fire, confined to container                          59.0
# Building fire                                                22.0
# Dumpster or other outside trash receptacle fire              12.0
# Mobile property (vehicle) fire, Other                         3.0
#
#                                                  Squirrel Hill North  \
# type_description
#                                                                  0.0
# Cooking fire, confined to container                             51.0
# Building fire                                                   14.0
# Dumpster or other outside trash receptacle fire                  5.0
# Mobile property (vehicle) fire, Other                            0.0
#
#                                                  Homewood North  ...  \
# type_description                                                 ...
#                                                             0.0  ...
# Cooking fire, confined to container                        24.0  ...
# Building fire                                              49.0  ...
# Dumpster or other outside trash receptacle fire             4.0  ...
# Mobile property (vehicle) fire, Other                       5.0  ...
#
#                                                  Spring Garden  Esplen  \
# type_description
#                                                            0.0     0.0
# Cooking fire, confined to container                        1.0     1.0
# Building fire                                              6.0     4.0
# Dumpster or other outside trash receptacle fire            0.0     0.0
# Mobile property (vehicle) fire, Other                      0.0     0.0
#
#                                                  Regent Square  Mt. Oliver  \
# type_description
#                                                            0.0         0.0
# Cooking fire, confined to container                        1.0         1.0
# Building fire                                              1.0         4.0
# Dumpster or other outside trash receptacle fire            0.0         0.0
# Mobile property (vehicle) fire, Other                      0.0         0.0
#
#                                                  Summer Hill  Allegheny West  \
# type_description
#                                                          0.0             0.0
# Cooking fire, confined to container                      2.0             1.0
# Building fire                                            4.0             5.0
# Dumpster or other outside trash receptacle fire          1.0             5.0
# Mobile property (vehicle) fire, Other                    1.0             0.0
#
#                                                  East Carnegie  \
# type_description
#                                                            0.0
# Cooking fire, confined to container                        3.0
# Building fire                                              2.0
# Dumpster or other outside trash receptacle fire            0.0
# Mobile property (vehicle) fire, Other                      1.0
#
#                                                  Mount Oliver Borough  Hays  \
# type_description
#                                                                   0.0   0.0
# Cooking fire, confined to container                               0.0   0.0
# Building fire                                                     2.0   2.0
# Dumpster or other outside trash receptacle fire                   0.0   0.0
# Mobile property (vehicle) fire, Other                             0.0   0.0
#
#                                                  Arlington Heights
# type_description
#                                                                0.0
# Cooking fire, confined to container                            7.0
# Building fire                                                  1.0
# Dumpster or other outside trash receptacle fire                0.0
# Mobile property (vehicle) fire, Other                          0.0
#
# [5 rows x 91 columns]

# %%
#final.plot(kind='bar',legend=False,figsize=(20,10),stacked=True)
test.plot.bar(figsize=(20,10),stacked=True)

# %% [markdown]
# Unfortunately,
